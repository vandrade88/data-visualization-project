# %% [markdown]
# # Part 1: ETL
# ## World Happiness Report 2016 - 2020

# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# # EXTRACT
# Store datasets into DataFrames

# %% [markdown]
# ### Dataset 1: 2020
#  - Webscrape from Wikipedia
#  - Store webscraped data into DataFrame

# %%
# 2020 table:
url = 'https://en.wikipedia.org/wiki/World_Happiness_Report#2020_report'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        Descriptions
#  0  The 2020 World Happiness Report, released on M...,
#                                          Descriptions
#  0  The 2019 World Happiness Report focuses commun...,
#                                          Descriptions
#  0  The 2018 iteration was released on 20 March an...,
#                                          Descriptions
#  0  The fifth World Happiness Report emphasizes th...,
#                                          Descriptions
#  0  The 2016 World Happiness Report -Rome Addition...,
#                                          Descriptions
#  0  The 2015 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2013 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2012 World Happiness Report was issued at ...,
#                                                   Table  \
# ...

# %%
df2020_raw = tables[9]
df2020_raw.head(200)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.809           1.285
# 1               2                   Denmark  7.646           1.327
# 2               3               Switzerland  7.560           1.391
# 3               4                   Iceland  7.504           1.327
# 4               5                    Norway  7.488           1.424
# ..            ...                       ...    ...             ...
# 148           149  Central African Republic  3.476           0.041
# 149           150                    Rwanda  3.312           0.343
# 150           151                  Zimbabwe  3.299           0.426
# 151           152               South Sudan  2.817           0.289
# 152           153               Afghanistan  2.567           0.301
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.500                    0.961                         0.662
# ...

# %% [markdown]
# ### Dataset 2: 2019
#  - Webscrape from Wikipedia
#  - Store webscraped data into DataFrame

# %%
# 2019 table:
url = 'https://en.wikipedia.org/wiki/World_Happiness_Report#2019_report'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        Descriptions
#  0  The 2020 World Happiness Report, released on M...,
#                                          Descriptions
#  0  The 2019 World Happiness Report focuses commun...,
#                                          Descriptions
#  0  The 2018 iteration was released on 20 March an...,
#                                          Descriptions
#  0  The fifth World Happiness Report emphasizes th...,
#                                          Descriptions
#  0  The 2016 World Happiness Report -Rome Addition...,
#                                          Descriptions
#  0  The 2015 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2013 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2012 World Happiness Report was issued at ...,
#                                                   Table  \
# ...

# %%
df2019_raw = tables[11]
df2019_raw.head(200)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# ..            ...                       ...    ...             ...
# 151           152                    Rwanda  3.334           0.359
# 152           153                  Tanzania  3.231           0.476
# 153           154               Afghanistan  3.203           0.350
# 154           155  Central African Republic  3.083           0.026
# 155           156               South Sudan  2.853           0.306
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.587                    0.986                         0.596
# ...

# %% [markdown]
# ### Dataset 3: 2018
#  - Webscrape from Wikipedia
#  - Store webscraped data into DataFrame

# %%
# 2018 table:
url = 'https://en.wikipedia.org/wiki/World_Happiness_Report#2018_report'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        Descriptions
#  0  The 2020 World Happiness Report, released on M...,
#                                          Descriptions
#  0  The 2019 World Happiness Report focuses commun...,
#                                          Descriptions
#  0  The 2018 iteration was released on 20 March an...,
#                                          Descriptions
#  0  The fifth World Happiness Report emphasizes th...,
#                                          Descriptions
#  0  The 2016 World Happiness Report -Rome Addition...,
#                                          Descriptions
#  0  The 2015 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2013 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2012 World Happiness Report was issued at ...,
#                                                   Table  \
# ...

# %%
df2018_raw = tables[13]
df2018_raw.head(200)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %% [markdown]
# ### Dataset 4: 2017
#  - Webscrape from Wikipedia
#  - Store webscraped data into DataFrame

# %%
# 2017 table:
url = 'https://en.wikipedia.org/wiki/World_Happiness_Report#2017_report'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        Descriptions
#  0  The 2020 World Happiness Report, released on M...,
#                                          Descriptions
#  0  The 2019 World Happiness Report focuses commun...,
#                                          Descriptions
#  0  The 2018 iteration was released on 20 March an...,
#                                          Descriptions
#  0  The fifth World Happiness Report emphasizes th...,
#                                          Descriptions
#  0  The 2016 World Happiness Report -Rome Addition...,
#                                          Descriptions
#  0  The 2015 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2013 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2012 World Happiness Report was issued at ...,
#                                                   Table  \
# ...

# %%
df2017_raw = tables[15]
df2017_raw.head(200)
# Out:
#     Overall Rank Change in rank                   Country  Score  \
# 0              1              3                    Norway  7.537
# 1              2              1                   Denmark  7.522
# 2              3            NaN                   Iceland  7.504
# 3              4              2               Switzerland  7.494
# 4              5            NaN                   Finland  7.469
# ..           ...            ...                       ...    ...
# 152          151              1                    Rwanda  3.471
# 153          152              4                     Syria  3.462
# 154          153              4                  Tanzania  3.349
# 155          154              3                   Burundi  2.905
# 156          155            NaN  Central African Republic  2.693
#
#      Change in score  GDP per capita  Social support  Healthy life expectancy  \
# 0              0.039           1.616           1.534                    0.797
# ...

# %% [markdown]
# ### Dataset 5: 2016
#  - Webscrape from Wikipedia
#  - Store webscraped data into DataFrame

# %%
# 2016 table:
url = 'https://en.wikipedia.org/wiki/World_Happiness_Report#2016_report'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                        Descriptions
#  0  The 2020 World Happiness Report, released on M...,
#                                          Descriptions
#  0  The 2019 World Happiness Report focuses commun...,
#                                          Descriptions
#  0  The 2018 iteration was released on 20 March an...,
#                                          Descriptions
#  0  The fifth World Happiness Report emphasizes th...,
#                                          Descriptions
#  0  The 2016 World Happiness Report -Rome Addition...,
#                                          Descriptions
#  0  The 2015 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2013 World Happiness Report has eight chap...,
#                                          Descriptions
#  0  The 2012 World Happiness Report was issued at ...,
#                                                   Table  \
# ...

# %%
df2016_raw = tables[18]
df2016_raw.head(200)
# Out:
#      Overall Rank[51][52]      Country  Score  Change OverPrior Year  \
# 0                       1      Denmark  7.526                 -0.401
# 1                       2  Switzerland  7.509                  0.035
# 2                       3      Iceland  7.501                  0.000
# 3                       4       Norway  7.498                  0.082
# 4                       5      Finland  7.413                 -0.259
# ..                    ...          ...    ...                    ...
# 152                   153        Benin  3.484                  0.154
# 153                   154  Afghanistan  3.360                  0.000
# 154                   155         Togo  3.303                  0.100
# 155                   156        Syria  3.069                  0.000
# 156                   157      Burundi  2.905                  0.000
#
#      GDP per capita  Social support  Healthy life expectancy  \
# 0               NaN             NaN                      NaN
# ...

# %% [markdown]
# # TRANSFORM
# Clean DataFrames

# %% [markdown]
# ### Dataset 1-5
#  - Create filtered database from specific columns
#  - Rename column headers
#  - Reset and rename index
#  - Confirm values are numeric
#  - Check for missing values
#  - Sort by country name
#  - Reorder columns

# %%
df2020_raw.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.809           1.285           1.500
# 1             2           Denmark  7.646           1.327           1.503
# 2             3       Switzerland  7.560           1.391           1.472
# 3             4           Iceland  7.504           1.327           1.548
# 4             5            Norway  7.488           1.424           1.495
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.961                         0.662       0.160
# 1                    0.979                         0.665       0.243
# 2                    1.041                         0.629       0.269
# 3                    1.001                         0.662       0.362
# 4                    1.008                         0.670       0.288
#
#    Perceptions of corruption
# 0                      0.478
# 1                      0.495
# ...

# %%
df2020_raw.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()
# Out:
#    Overall Rank Country or Region  Score  GDP per Capita  Social Support  \
# 0             1           Finland  7.809           1.285           1.500
# 1             2           Denmark  7.646           1.327           1.503
# 2             3       Switzerland  7.560           1.391           1.472
# 3             4           Iceland  7.504           1.327           1.548
# 4             5            Norway  7.488           1.424           1.495
#
#    Healthy Life Expectancy  Freedom to Make Life Choices  Generosity  \
# 0                    0.961                         0.662       0.160
# 1                    0.979                         0.665       0.243
# 2                    1.041                         0.629       0.269
# 3                    1.001                         0.662       0.362
# 4                    1.008                         0.670       0.288
#
#    Perceptions of Corruption
# 0                      0.478
# 1                      0.495
# ...

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()
# Out:
#   Country or Region  Score  Overall Rank  GDP per Capita  Social Support  \
# 0           Finland  7.809             1           1.285           1.500
# 1           Denmark  7.646             2           1.327           1.503
# 2       Switzerland  7.560             3           1.391           1.472
# 3           Iceland  7.504             4           1.327           1.548
# 4            Norway  7.488             5           1.424           1.495
#
#    Healthy Life Expectancy  Freedom to Make Life Choices  Generosity  \
# 0                    0.961                         0.662       0.160
# 1                    0.979                         0.665       0.243
# 2                    1.041                         0.629       0.269
# 3                    1.001                         0.662       0.362
# 4                    1.008                         0.670       0.288
#
#    Perceptions of Corruption
# 0                      0.478
# 1                      0.495
# ...

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()
# Out:
#     Country or Region  Score  Overall Rank  GDP per Capita  Social Support  \
# 152       Afghanistan  2.567           153           0.301           0.356
# 104           Albania  4.883           105           0.907           0.830
# 99            Algeria  5.005           100           0.944           1.143
# 54          Argentina  5.975            55           1.028           1.373
# 115           Armenia  4.677           116           0.808           1.035
#
#      Healthy Life Expectancy  Freedom to Make Life Choices  Generosity  \
# 152                    0.266                         0.000       0.135
# 104                    0.846                         0.462       0.171
# 99                     0.745                         0.084       0.119
# 54                     0.850                         0.521       0.070
# 115                    0.776                         0.378       0.107
#
#      Perceptions of Corruption
# 152                      0.001
# ...

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()
# Out:
#   Country or Region  Score  Overall Rank  GDP per Capita  Social Support  \
# 0       Afghanistan  2.567           153           0.301           0.356
# 1           Albania  4.883           105           0.907           0.830
# 2           Algeria  5.005           100           0.944           1.143
# 3         Argentina  5.975            55           1.028           1.373
# 4           Armenia  4.677           116           0.808           1.035
#
#    Healthy Life Expectancy  Freedom to Make Life Choices  Generosity  \
# 0                    0.266                         0.000       0.135
# 1                    0.846                         0.462       0.171
# 2                    0.745                         0.084       0.119
# 3                    0.850                         0.521       0.070
# 4                    0.776                         0.378       0.107
#
#    Perceptions of Corruption
# 0                      0.001
# 1                      0.025
# ...

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()
# Out:
#    Country or Region  Score  Overall Rank  GDP per Capita  Social Support  \
# id
# 1        Afghanistan  2.567           153           0.301           0.356
# 2            Albania  4.883           105           0.907           0.830
# 3            Algeria  5.005           100           0.944           1.143
# 4          Argentina  5.975            55           1.028           1.373
# 5            Armenia  4.677           116           0.808           1.035
#
#     Healthy Life Expectancy  Freedom to Make Life Choices  Generosity  \
# id
# 1                     0.266                         0.000       0.135
# 2                     0.846                         0.462       0.171
# 3                     0.745                         0.084       0.119
# 4                     0.850                         0.521       0.070
# 5                     0.776                         0.378       0.107
#
#     Perceptions of Corruption
# id
# 1                       0.001
# ...

# %%
df2020.dtypes
# Out:
# Country or Region                object
# Score                           float64
# Overall Rank                      int64
# GDP per Capita                  float64
# Social Support                  float64
# Healthy Life Expectancy         float64
# Freedom to Make Life Choices    float64
# Generosity                      float64
# Perceptions of Corruption       float64
# dtype: object

# %%
df2020.isna().sum()
# Out:
# Country or Region               0
# Score                           0
# Overall Rank                    0
# GDP per Capita                  0
# Social Support                  0
# Healthy Life Expectancy         0
# Freedom to Make Life Choices    0
# Generosity                      0
# Perceptions of Corruption       0
# dtype: int64

# %%
df2020_raw.head()

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()

# %%
df2020.dtypes

# %%
df2020.isna().sum()

# %%
df2020_raw.head()

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()

# %%
df2020.dtypes

# %%
df2020.isna().sum()

# %%
df2020_raw.head()

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()

# %%
df2020.dtypes

# %%
df2020.isna().sum()

# %%
df2020_raw.head()

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()

# %%
df2020.dtypes

# %%
df2020.isna().sum()

# %%
df2020_raw.head()

# %%
df2020 = df2020_raw.rename(columns = {"Overall rank": "Overall Rank", "Country or region": "Country or Region",\
                                      "GDP per capita": "GDP per Capita", "Social support": "Social Support",\
                                      "Healthy life expectancy": "Healthy Life Expectancy", "Freedom to make life choices": "Freedom to Make Life Choices",\
                                      "Perceptions of corruption": "Perceptions of Corruption"})
df2020.head()

# %%
df2020 = df2020[["Country or Region", "Score", "Overall Rank", "GDP per Capita", "Social Support",\
                "Healthy Life Expectancy", "Freedom to Make Life Choices", "Generosity", "Perceptions of Corruption"]].copy()
df2020.head()

# %%
df2020 = df2020.sort_values(by = 'Country or Region')
df2020.head()

# %%
df2020 = df2020.reset_index(drop=True)
df2020.head()

# %%
df2020.index += 1; df2020.index.name='id'
df2020.head()

# %%
df2020.dtypes

# %%
df2020.isna().sum()
